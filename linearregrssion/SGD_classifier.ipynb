# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error , mean_absolute_error , r2_score
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer 
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectFromModel
import scipy
import joblib
from sklearn.datasets import fetch_openml 
from sklearn.datasets import make_moons

# %%
x,y = make_moons(n_samples=50, noise=0.1, random_state=42)
plt.scatter(x[:, 0], x[:, 1], c=y, cmap=plt.cm.Paired)

# %%
x,y = make_moons(n_samples=50, noise=None, random_state=42)
plt.scatter(x[:, 0], x[:, 1], c=y, cmap=plt.cm.Paired)

# %%
X_train,X_test = mnsit.data[:60000],mnsit.data[60000:]
y_train,y_test = mnsit.target[:60000],mnsit.target[60000:]

# %%
arr1 = np.array([1,2,3,4,6,10])
arr2 = np.array([1,20,30,4,6,10])
(arr2>arr1).argmax()
# Out:
# np.int64(1)

# %%
class Test : 
    var1 = [1,3,4]
    def __init__(self):
        self.var2 = [14,4]
        
Test().var2.append(1)
print(Test().var2)
# Out:
# [14, 4]

# %%
def plot_img(img):
    plt.imshow(img.reshape(28,-1))
    
plot_img(X_train[0])

# %%
y_train_5 = (y_train == '5')

# %%
from sklearn.linear_model import SGDClassifier
sgd = SGDClassifier(random_state=42)
sgd.fit(X_train,y_train_5)
# Out:
# SGDClassifier(random_state=42)

# %%
y_pred = sgd.predict(X_test)

# %%
plot_img(X_test[-2])

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold,cross_val_predict
from sklearn.base import clone
from sklearn.metrics import confusion_matrix

# %%
strata = StratifiedKFold(n_splits=3)
cloned_model = clone(sgd)
cloned_model
# Out:
# SGDClassifier(random_state=42)

# %%
y_pred = cross_val_predict(sgd,X_train,y_train_5,cv=3)

# %%
y_train_5.shape
# Out:
# (60000,)

# %%
y_score = sgd.decision_function(X_train)

# %%
y_score > 3000
# Out:
# array([False, False, False, ...,  True, False, False])
